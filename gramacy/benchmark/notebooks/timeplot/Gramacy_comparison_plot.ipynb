# %% [markdown]
# # Gramacy Comparison Plots

# %% [markdown]
# # matplot lib params

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Adjust Matplotlib font settings
plt.rcParams.update({
    'font.size': 20,
    'svg.fonttype': 'none',
    'axes.labelsize': 20,  # Increased for better readability
    'axes.titlesize': 20,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20
})
# Define color schemes
color_scheme = {
    'Ax': '#D62728',        # Muted red
    'HyperOpt': '#1F77B4',  # Muted blue
    'Random': '#2CA02C',    # Green
}
custom_colors = {
    'Paddy': '#FFA500',     # Orange
    'Evotorch EA': '#6A0DAD', # Purple
    'Evotorch GA': '#FFC0CB'  # Pink
}

# %% [markdown]
# # aglorithm best arrays

# %%
# Define all parameter sets
#original
ax_params = np.array([1.00000000e+00, 6.74815882e-01, -1.91461524e-01, 8.03391861e-01,
                      -6.54266187e-01, 9.72552779e-01, -4.08678100e-01, 9.32436152e-02,
                      5.04963989e-04, 7.74992756e-01, -7.30223163e-01, 2.49635909e-01,
                      6.95097365e-02, 5.59492729e-02, -1.31799856e-02, 9.26701440e-01,
                      1.91744199e-02, 1.35748323e-02, -2.19835728e-01, 5.42483517e-01,
                      3.13189006e-01, 5.94743218e-01, -8.43072269e-02, 3.73348481e-01,
                      1.94538458e-01, 3.91053766e-01, -2.95978303e-01, 5.00302129e-01,
                      9.10053813e-01, 8.42684787e-01, -4.86739743e-01, 8.08429657e-01,
                      3.58523346e-01, 2.78064331e-01, -7.54454211e-01, 4.46223901e-01,
                      3.46658292e-01, 5.52804053e-01, -2.32142417e-02, 6.60737051e-01,
                      -2.94338658e-01, 1.18386243e-01, -1.95129750e-01, -1.14685734e-02,
                      3.64024171e-01, 8.72155915e-01, 3.94991511e-01, 6.48153469e-01,
                      2.47228828e-02, 6.78111554e-01, -2.32024206e-01, 4.80505339e-01,
                      1.03670621e-01, 5.32516728e-01, -1.75972083e-01, 6.96558144e-01,
                      -1.41584498e-01, -8.24850449e-02, -1.45936513e-01, 8.00610522e-01,
                      3.89469222e-01, 3.38593292e-01, -2.55439587e-01, 3.95583639e-02,
                      8.65438544e-02])

#up
paddy_params = np.array([0.9395181883349976, 0.5768198459111651, -1.0, 0.7882400501353739, -0.030218997755188756, 0.873239219967684, -0.837463316074117, -0.09926608329366571, -0.20775762381704843, -0.3017269863101054, 
 -1.0, -0.11080139048953688, 1.0, 0.7230467707949447, 0.43283431156323815, 1.0, -0.621339089828348, 0.3211493631968323, 0.03577401704367553, 0.9101494808533586, 0.3484634620221961, 1.0,
 -0.2044887252978687, 0.47952769041552157, 0.006540792877675949, 0.13767984722971705, -0.6176495320094357, 0.6187877107691784, 0.36497195594658816, -0.3435555204949388, -0.5630925409915268, 
 -0.6574896194966681, -0.11049528581114032, -0.07171004973372441, 1.0, 0.9983482682621965, -0.21721748380074526, 1.0, 0.08734348472428288, 0.6376331579051201, -1.0, -0.3185346733229159, 0.7051645425614352, 
 0.36409628745994116, -1.0, 0.24449249825191244, 0.542240846469707, 0.5514818903020748, -0.9657976357787889, -0.10924368383908847, 1.0, 0.863642490355833, -0.1854962497016045, -0.4052996727877378, 
 0.8312223053057244, 0.4187457728204446, 0.3113742684620918, 1.0, 0.993318181239131, 0.7108158778244631, -1.0, 0.03246208332353974, 0.10261229936595401, 0.06045327843338262, -0.5519248900657672])



#up 8xparallel
hyperopt_params = np.array([
    0.999730,  # x0
    0.512948,  # x1
    -0.265953, # x2
    0.648123,  # x3
    -0.934735, # x4
    0.792786,  # x5
    -0.518660, # x6
    -0.999783, # x7
    -0.738484, # x8
    0.865754,  # x9
    0.100989,  # x10
    0.290027,  # x11
    0.247988,  # x12
    0.851415,  # x13
    0.419785,  # x14
    0.030112,  # x15
    -0.339627, # x16
    -0.373123, # x17
    0.533926,  # x18
    0.676705,  # x19
    0.737798,  # x20
    0.942058,  # x21
    0.116275,  # x22
    0.479156,  # x23
    0.501048,  # x24
    0.538934,  # x25
    -0.289086, # x26
    0.319951,  # x27
    -0.182670, # x28
    -0.376765, # x29
    0.324185,  # x30
    0.733765,  # x31
    0.891151,  # x32
    0.063182,  # x33
    0.101753,  # x34
    0.796996,  # x35
    0.116396,  # x36
    0.052480,  # x37
    -0.255945, # x38
    0.564903,  # x39
    0.677146,  # x40
    0.562798,  # x41
    0.682372,  # x42
    0.778467,  # x43
    -0.298374, # x44
    0.217983,  # x45
    0.261992,  # x46
    0.884750,  # x47
    -0.297854, # x48
    0.317909,  # x49
    0.208256,  # x50
    0.626877,  # x51
    -0.335429, # x52
    0.224679,  # x53
    0.667798,  # x54
    0.518203,  # x55
    0.006282,  # x56
    0.714821,  # x57
    0.209086,  # x58
    0.890550,  # x59
    -0.610695, # x60
    -0.349475, # x61
    0.534236,  # x62
    0.521923,  # x63
    0.099285   # x64
])

#up
random_params = np.array([
    0.534248, 0.336419, 0.241098, 0.828474, -0.565638, 0.749414, 0.394106, 0.712255,
    0.455226, 0.247473, -0.651403, 0.800757, -0.120502, -0.967018, -0.835703, 0.553574,
    -0.204484, 0.991842, -0.135703, 0.393455, -0.066352, 0.362537, 0.265049, -0.161412,
    -0.018913, 0.401545, -0.483780, -0.334323, 0.850494, 0.103520, -0.610513, -0.044620,
    0.442545, 0.834863, -0.654387, 0.155729, 0.894423, 0.767572, 0.504816, 0.142155,
    -0.332310, 0.348061, -0.905104, 0.979073, -0.686283, -0.820455, -0.748214, 0.728673,
    0.581560, -0.237890, 0.187192, 0.939750, 0.639484, 0.585598, 0.560760, 0.323870,
    -0.194305, 0.905188, 0.142508, -0.288944, -0.170582, 0.791214, -0.778300, -0.635127,
    -0.612724
])
#up
evotorch_ea_params = np.array( [0.555032, -0.421396, -0.039718, 1.000000, 0.473194, 1.000000, -0.438293, 0.410312, 0.637964,
                                 0.421943, -0.384852, 0.757667, -0.077829, 0.020931, -0.438955, 0.607343, -0.276627, -1.000000,
                                   0.138192, 0.151005, 0.727896, 0.200235, 1.000000, 1.000000, 0.598561, -0.423292, -0.907224, 0.145763,
                                     0.950367, 0.837043, -0.460130, 0.891099, -0.083274, 0.602385, 0.790176, 1.000000, -0.120678, 0.818976, 
                                     -1.000000, 0.117552, -0.927491, -0.333841, -0.243182, 0.261306,
                                 -0.486217, 0.472433, 1.000000, 0.228986, 0.101914, 0.541844, 0.967481, 0.338229, -0.196856, 0.102161, 0.064274,
                                   0.730459, -0.908941, -0.165005, 0.652585, 0.717854, -0.474399, 0.212988, -0.787459, -0.473793, -0.601708])
#up
evotorch_ga_params = np.array([1.000000, 0.426597, 0.183862, 1.000000, -0.781481, 1.000000, -0.311593, 0.182770, 0.407699, 0.079535, -0.944522, 0.182919, 0.641939, 0.321236,
   -0.490833, 0.307256, -0.369914, -0.870059, -0.842257, 0.333124, 0.759238, -0.112103, 0.342575, 0.763944, 0.915587, 0.785511, -1.000000, 0.854384, 
   0.031469, -0.046687, -0.928346, 0.825646, 0.934398, 0.227399, -0.794930, -0.141421, 0.933790, 0.847709, -0.835139, -0.192417, 0.342317, 0.470523, 0.620780, 0.370924,
   -0.380333, 0.461476, -0.019478, 0.097687, -0.138553, 0.754323, 0.293798, 1.000000, 0.270592, -0.241135, -0.983813, 0.703467, 0.803037, 1.000000, -0.326016, 0.265883, -0.441806,
     -0.828644, 0.762406, 1.000000, -0.494826])

# %% [markdown]
# # update true funciton in legend

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Assuming you have defined custom_colors and other parameter sets elsewhere
# Example:
# custom_colors = {
#     'Evotorch EA': '#1f77b4',
#     # Add other colors as needed
# }

# Set global plot customizations for spines and grid
def customize_plot():
    ax = plt.gca()  # Get current axis
    # Customize grid
    plt.grid(True, linestyle='--', alpha=1.0)  # Fully opaque grid
    # Customize spines
    for spine in ax.spines.values():
        spine.set_color('black')  # Set spine color to black
        spine.set_linewidth(1.5)  # Set spine width to 1.5
    # Customize tick parameters
    ax.tick_params(axis='both', which='major', labelsize=20)  # Increase tick label size
    # Optional: Customize minor ticks if needed
    # ax.tick_params(axis='both', which='minor', labelsize=14)

# Define all parameter sets and other parts of the script
# Your parameter definitions, calculations, and plotting code here...

# Generate x values excluding 0
x_vals = np.linspace(-0.5, 2.5, 3001)
x_vals = x_vals[x_vals != 0]

# Calculate true Gramacy-Lee function
target_y = (np.sin(10 * np.pi * x_vals) / (2 * x_vals)) + ((x_vals - 1) ** 4)

# Function to calculate predictions
def calc_pred(params, x_vals):
    c0 = params[0]
    cos_coeffs = params[1::2]
    sin_coeffs = params[2::2]
    n_max = len(cos_coeffs)
    
    y_pred = np.full_like(x_vals, c0)
    for n in range(1, n_max + 1):
        y_pred += cos_coeffs[n-1] * np.cos(n * x_vals)
        y_pred += sin_coeffs[n-1] * np.sin(n * x_vals)
    return y_pred

# Calculate predictions for all parameter sets
ax_pred = calc_pred(ax_params, x_vals)
paddy_pred = calc_pred(paddy_params, x_vals)
hyperopt_pred = calc_pred(hyperopt_params, x_vals)
evotorch_ga_pred = calc_pred(evotorch_ga_params, x_vals)
evotorch_ea_pred = calc_pred(evotorch_ea_params, x_vals)
random_pred = calc_pred(random_params, x_vals)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot true function
true_line = plt.plot(x_vals, target_y, 'k-', linewidth=2, alpha=1)[0]

# Plot optimization methods with specific colors
# Uncomment and modify as needed
#ax_line = plt.plot(x_vals, ax_pred, color=color_scheme['Ax'], linewidth=2, alpha=1)[0]
hyperopt_line = plt.plot(x_vals, hyperopt_pred, color=color_scheme['HyperOpt'], linewidth=2, alpha=1)[0]
#random_line = plt.plot(x_vals, random_pred, color=color_scheme['Random'], linewidth=2, alpha=1)[0]
#paddy_line = plt.plot(x_vals, paddy_pred, color=custom_colors['Paddy'], linewidth=2, alpha=1)[0]
#evotorch_ea_line = plt.plot(x_vals, evotorch_ea_pred, color=custom_colors['Evotorch EA'], linewidth=2, alpha=1)[0]
#evotorch_ga_line = plt.plot(x_vals, evotorch_ga_pred, color=custom_colors['Evotorch GA'], linewidth=2, alpha=1)[0]

# Apply the customizations
customize_plot()

# Create legend handles using Patches
legend_handles = [
    Patch(facecolor='black', edgecolor='black', label='Gramacy & Lee'),
    #Patch(facecolor=color_scheme['Ax'], edgecolor='black', label='Ax'),
    Patch(facecolor=color_scheme['HyperOpt'], edgecolor='black', label='HyperOpt'),
    #Patch(facecolor=color_scheme['Random'], edgecolor='black', label='Random'),
    #Patch(facecolor=custom_colors['Paddy'], edgecolor='black', label='Paddy'),
    #Patch(facecolor=custom_colors['Evotorch EA'], edgecolor='black', label='Evotorch EA'),
    #Patch(facecolor=custom_colors['Evotorch GA'], edgecolor='black', label='Evotorch GA'),
]

# Add the legend
plt.legend(handles=legend_handles, loc='upper right', ncol=2, fontsize=16, frameon=True)

# Final adjustments
plt.xlabel('x', fontsize=20)
plt.ylabel('f(x)', fontsize=20)
plt.tight_layout()
plt.xlim(-0.5, 2.5)  # Restrict x-axis range from -0.5 to 2.5

# Save plot
plt.savefig("compare_plots/gramacy_lee_comparison_Hyperopt.png", format="png", bbox_inches='tight', dpi=300)
plt.show()

# Calculate and print MSE values
print("\nMean Squared Errors:")
print("-" * 30)
# Uncomment and modify as needed
#print(f"Ax MSE:         {np.mean((target_y - ax_pred) ** 2):.6f}")
# print(f"HyperOpt MSE:   {np.mean((target_y - hyperopt_pred) ** 2):.6f}")
#print(f"Random MSE:     {np.mean((target_y - random_pred) ** 2):.6f}")
#print(f"Paddy MSE:      {np.mean((target_y - paddy_pred) ** 2):.6f}")
#print(f"EvoTorch EA MSE: {np.mean((target_y - evotorch_ea_pred) ** 2):.6f}")
#print(f"EvoTorch GA MSE: {np.mean((target_y - evotorch_ga_pred) ** 2):.6f}")
# Out:
# Mean Squared Errors:
# ------------------------------
