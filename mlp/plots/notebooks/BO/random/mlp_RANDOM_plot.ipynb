# %%
import pandas as pd
import os
import re
# Out:
# /scratch/gilbreth/iyer95/conda_envs/plot/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /scratch/gilbreth/iyer95/conda_envs/plot/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# # MLP RANDOM

# %%
# Path to the uploaded file
file_path = '../../../plotting_data/raw/MLP_Random_10Jan25_7704200.log'
# Define the paths to save the results
iteration_file_path = 'MLP_Random_10Jan25_7704200_ITERATION.csv'
summary_file_path = 'MLP_Random_10Jan25_7704200_SUMMARY.csv'

def MLP_Random_updated(file_path):
    """
    Process a RANDOM log file to extract:
        - Cross-Validation F1 for each Trial and Iteration.
        - Summary details for each Trial, including Best Trial F1 and Trial Time.

    Args:
        file_path (str): Path to the log file.

    Returns:
        tuple: Two DataFrames:
            - Iteration DataFrame with Trial, Iteration, and Cross-Validation F1.
            - Summary DataFrame with Trial, Best Trial F1, Best Parameters, and Time.
    """
    # Open and read the log file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Initialize lists to store extracted data
    iteration_data = []
    summary_data = []

    # Define regex patterns
    trial_pattern = re.compile(r"Trial (\d+)/\d+")
    iteration_pattern = re.compile(r"Iteration (\d+)/\d+")
    cv_f1_pattern = re.compile(r"Cross-Validation F1: ([\d\.]+)")
    trial_summary_pattern = re.compile(r"Trial (\d+) Summary:")
    best_f1_pattern = re.compile(r"Best Trial F1: ([\d\.]+)")
    best_params_pattern = re.compile(r"Best Parameters: (.+)")
    trial_time_pattern = re.compile(r"Trial Time: ([\d\.]+) seconds")  # New pattern for Trial Time

    # Variables to track current trial, iteration, and summary details
    current_trial = None
    current_iteration = None
    summary_trial = None  # Variable to track the trial being summarized
    best_f1 = None
    best_params = None
    trial_time = None  # Variable to store Trial Time

    for line in lines:
        line = line.strip()  # Remove leading/trailing whitespace

        # Check for Trial (during iterations)
        trial_match = trial_pattern.search(line)
        if trial_match:
            current_trial = int(trial_match.group(1))
            print(f"Debug: Found Trial {current_trial} during iterations")
            continue

        # Check for Iteration
        iteration_match = iteration_pattern.search(line)
        if iteration_match:
            current_iteration = int(iteration_match.group(1))
            print(f"Debug: Found Iteration {current_iteration} for Trial {current_trial}")
            continue

        # Check for Cross-Validation F1
        cv_f1_match = cv_f1_pattern.search(line)
        if cv_f1_match and current_trial is not None and current_iteration is not None:
            f1_score = float(cv_f1_match.group(1))
            print(f"Debug: Found Cross-Validation F1 {f1_score} for Trial {current_trial}, Iteration {current_iteration}")
            iteration_data.append((current_trial, current_iteration, f1_score))
            continue

        # Check for Trial Summary
        trial_summary_match = trial_summary_pattern.search(line)
        if trial_summary_match:
            # If there's an ongoing summary, append it before starting a new one
            if summary_trial is not None and best_f1 is not None and best_params is not None and trial_time is not None:
                summary_data.append((summary_trial, best_f1, best_params, trial_time))
                print(f"Debug: Saved summary for Trial {summary_trial}")

            # Start a new trial summary
            summary_trial = int(trial_summary_match.group(1))
            best_f1 = None
            best_params = None
            trial_time = None  # Reset Trial Time for the new trial
            print(f"Debug: Starting summary collection for Trial {summary_trial}")
            continue

        # Check for Trial Time
        trial_time_match = trial_time_pattern.search(line)
        if trial_time_match and summary_trial is not None:
            trial_time = float(trial_time_match.group(1))
            print(f"Debug: Found Trial Time {trial_time} seconds for Trial {summary_trial}")
            continue

        # Check for Best Trial F1
        best_f1_match = best_f1_pattern.search(line)
        if best_f1_match and summary_trial is not None:
            best_f1 = float(best_f1_match.group(1))
            print(f"Debug: Found Best Trial F1 {best_f1} for Trial {summary_trial}")
            continue

        # Check for Best Parameters
        best_params_match = best_params_pattern.search(line)
        if best_params_match and summary_trial is not None:
            best_params = best_params_match.group(1)
            print(f"Debug: Found Best Parameters for Trial {summary_trial}: {best_params}")
            # After finding all summary details, append to summary_data
            if best_f1 is not None and trial_time is not None:
                summary_data.append((summary_trial, best_f1, best_params, trial_time))
                print(f"Debug: Saved summary for Trial {summary_trial}")
                # Reset summary variables
                summary_trial = None
                best_f1 = None
                best_params = None
                trial_time = None
            continue

    # In case the last trial summary wasn't appended inside the loop
    if summary_trial is not None and best_f1 is not None and best_params is not None and trial_time is not None:
        summary_data.append((summary_trial, best_f1, best_params, trial_time))
        print(f"Debug: Saved summary for Trial {summary_trial} at end of file")

    # Create DataFrames for the results
    iteration_df = pd.DataFrame(iteration_data, columns=["Trial", "Iteration", "F1_Score"])
    summary_df = pd.DataFrame(summary_data, columns=["Trial", "Best_F1_Score", "Best_Parameters", "Time"])

    return iteration_df, summary_df

# Process the file
iteration_df, summary_df = MLP_Random_updated(file_path)

# Define paths for iteration and summary data
# Adjusted to match the naming convention
# iteration_file_path = 'mlp_RANDOM_07Jan25_Paper_7665194_ITERATION.csv'
# summary_file_path = 'mlp_RANDOM_07Jan25_Paper_7665194_SUMMARY.csv'

# Save the results to the specified paths
for path in [iteration_file_path, summary_file_path]:
    if os.path.dirname(path):
        os.makedirs(os.path.dirname(path), exist_ok=True)

iteration_df.to_csv(iteration_file_path, index=False)
summary_df.to_csv(summary_file_path, index=False)

print(f"Iteration data saved to: {iteration_file_path}")
print(f"Trial summary saved to: {summary_file_path}")
# Out:
# Debug: Found Trial 1 during iterations
# Debug: Found Iteration 1 for Trial 1
# Debug: Found Cross-Validation F1 0.2863 for Trial 1, Iteration 1
# Debug: Found Iteration 2 for Trial 1
# Debug: Found Cross-Validation F1 0.2515 for Trial 1, Iteration 2
# Debug: Found Iteration 3 for Trial 1
# Debug: Found Cross-Validation F1 0.3294 for Trial 1, Iteration 3
# Debug: Found Iteration 4 for Trial 1
# Debug: Found Cross-Validation F1 0.4113 for Trial 1, Iteration 4
# Debug: Found Iteration 5 for Trial 1
# Debug: Found Cross-Validation F1 0.336 for Trial 1, Iteration 5
# Debug: Found Iteration 6 for Trial 1
# Debug: Found Cross-Validation F1 0.3765 for Trial 1, Iteration 6
# Debug: Found Iteration 7 for Trial 1
# Debug: Found Cross-Validation F1 0.2775 for Trial 1, Iteration 7
# Debug: Found Iteration 8 for Trial 1
# Debug: Found Cross-Validation F1 0.341 for Trial 1, Iteration 8
# Debug: Found Iteration 9 for Trial 1
# Debug: Found Cross-Validation F1 0.4788 for Trial 1, Iteration 9
# Debug: Found Iteration 10 for Trial 1
# Debug: Found Cross-Validation F1 0.503 for Trial 1, Iteration 10
# Debug: Found Iteration 11 for Trial 1
# Debug: Found Cross-Validation F1 0.4541 for Trial 1, Iteration 11
# Debug: Found Iteration 12 for Trial 1
# Debug: Found Cross-Validation F1 0.3226 for Trial 1, Iteration 12
# Debug: Found Iteration 13 for Trial 1
# Debug: Found Cross-Validation F1 0.4844 for Trial 1, Iteration 13
# Debug: Found Iteration 14 for Trial 1
# Debug: Found Cross-Validation F1 0.4195 for Trial 1, Iteration 14
# Debug: Found Iteration 15 for Trial 1
# Debug: Found Cross-Validation F1 0.2703 for Trial 1, Iteration 15
# Debug: Found Iteration 16 for Trial 1
# Debug: Found Cross-Validation F1 0.4616 for Trial 1, Iteration 16
# Debug: Found Iteration 17 for Trial 1
# Debug: Found Cross-Validation F1 0.3296 for Trial 1, Iteration 17
# Debug: Found Iteration 18 for Trial 1
# Debug: Found Cross-Validation F1 0.2829 for Trial 1, Iteration 18
# Debug: Found Iteration 19 for Trial 1
# Debug: Found Cross-Validation F1 0.2895 for Trial 1, Iteration 19
# Debug: Found Iteration 20 for Trial 1
# Debug: Found Cross-Validation F1 0.2743 for Trial 1, Iteration 20
# Debug: Found Iteration 21 for Trial 1
# Debug: Found Cross-Validation F1 0.3136 for Trial 1, Iteration 21
# Debug: Found Iteration 22 for Trial 1
# Debug: Found Cross-Validation F1 0.2881 for Trial 1, Iteration 22
# Debug: Found Iteration 23 for Trial 1
# Debug: Found Cross-Validation F1 0.4259 for Trial 1, Iteration 23
# Debug: Found Iteration 24 for Trial 1
# Debug: Found Cross-Validation F1 0.3274 for Trial 1, Iteration 24
# Debug: Found Iteration 25 for Trial 1
# Debug: Found Cross-Validation F1 0.4796 for Trial 1, Iteration 25
# Debug: Found Iteration 26 for Trial 1
# Debug: Found Cross-Validation F1 0.2821 for Trial 1, Iteration 26
# Debug: Found Iteration 27 for Trial 1
# Debug: Found Cross-Validation F1 0.4323 for Trial 1, Iteration 27
# Debug: Found Iteration 28 for Trial 1
# Debug: Found Cross-Validation F1 0.2904 for Trial 1, Iteration 28
# Debug: Found Iteration 29 for Trial 1
# Debug: Found Cross-Validation F1 0.2843 for Trial 1, Iteration 29
# Debug: Found Iteration 30 for Trial 1
# Debug: Found Cross-Validation F1 0.4722 for Trial 1, Iteration 30
# Debug: Found Iteration 31 for Trial 1
# Debug: Found Cross-Validation F1 0.4345 for Trial 1, Iteration 31
# Debug: Found Iteration 32 for Trial 1
# Debug: Found Cross-Validation F1 0.5102 for Trial 1, Iteration 32
# Debug: Found Iteration 33 for Trial 1
# Debug: Found Cross-Validation F1 0.4509 for Trial 1, Iteration 33
# Debug: Found Iteration 34 for Trial 1
# Debug: Found Cross-Validation F1 0.3847 for Trial 1, Iteration 34
# Debug: Found Iteration 35 for Trial 1
# Debug: Found Cross-Validation F1 0.465 for Trial 1, Iteration 35
# Debug: Found Iteration 36 for Trial 1
# Debug: Found Cross-Validation F1 0.4568 for Trial 1, Iteration 36
# Debug: Found Iteration 37 for Trial 1
# Debug: Found Cross-Validation F1 0.2988 for Trial 1, Iteration 37
# Debug: Found Iteration 38 for Trial 1
# Debug: Found Cross-Validation F1 0.3282 for Trial 1, Iteration 38
# Debug: Found Iteration 39 for Trial 1
# Debug: Found Cross-Validation F1 0.4876 for Trial 1, Iteration 39
# Debug: Found Iteration 40 for Trial 1
# Debug: Found Cross-Validation F1 0.377 for Trial 1, Iteration 40
# Debug: Found Iteration 41 for Trial 1
# Debug: Found Cross-Validation F1 0.3144 for Trial 1, Iteration 41
# Debug: Found Iteration 42 for Trial 1
# Debug: Found Cross-Validation F1 0.2461 for Trial 1, Iteration 42
# Debug: Found Iteration 43 for Trial 1
# Debug: Found Cross-Validation F1 0.3262 for Trial 1, Iteration 43
# Debug: Found Iteration 44 for Trial 1
# Debug: Found Cross-Validation F1 0.3999 for Trial 1, Iteration 44
# Debug: Found Iteration 45 for Trial 1
# Debug: Found Cross-Validation F1 0.3722 for Trial 1, Iteration 45
# Debug: Found Iteration 46 for Trial 1
# Debug: Found Cross-Validation F1 0.4866 for Trial 1, Iteration 46
# Debug: Found Iteration 47 for Trial 1
# Debug: Found Cross-Validation F1 0.5178 for Trial 1, Iteration 47
# Debug: Found Iteration 48 for Trial 1
# Debug: Found Cross-Validation F1 0.5132 for Trial 1, Iteration 48
# Debug: Found Iteration 49 for Trial 1
# Debug: Found Cross-Validation F1 0.4702 for Trial 1, Iteration 49
# Debug: Found Iteration 50 for Trial 1
# Debug: Found Cross-Validation F1 0.467 for Trial 1, Iteration 50
# Debug: Found Iteration 51 for Trial 1
# Debug: Found Cross-Validation F1 0.3827 for Trial 1, Iteration 51
# Debug: Found Iteration 52 for Trial 1
# Debug: Found Cross-Validation F1 0.359 for Trial 1, Iteration 52
# Debug: Found Iteration 53 for Trial 1
# Debug: Found Cross-Validation F1 0.4401 for Trial 1, Iteration 53
# Debug: Found Iteration 54 for Trial 1
# Debug: Found Cross-Validation F1 0.3726 for Trial 1, Iteration 54
# Debug: Found Iteration 55 for Trial 1
# Debug: Found Cross-Validation F1 0.4884 for Trial 1, Iteration 55
# Debug: Found Iteration 56 for Trial 1
# Debug: Found Cross-Validation F1 0.4323 for Trial 1, Iteration 56
# Debug: Found Iteration 57 for Trial 1
# Debug: Found Cross-Validation F1 0.4882 for Trial 1, Iteration 57
# Debug: Found Iteration 58 for Trial 1
# Debug: Found Cross-Validation F1 0.5096 for Trial 1, Iteration 58
# Debug: Found Iteration 59 for Trial 1
# Debug: Found Cross-Validation F1 0.3266 for Trial 1, Iteration 59
# Debug: Found Iteration 60 for Trial 1
# Debug: Found Cross-Validation F1 0.3004 for Trial 1, Iteration 60
# Debug: Found Iteration 61 for Trial 1
# Debug: Found Cross-Validation F1 0.461 for Trial 1, Iteration 61
# Debug: Found Iteration 62 for Trial 1
# Debug: Found Cross-Validation F1 0.4473 for Trial 1, Iteration 62
# Debug: Found Iteration 63 for Trial 1
# Debug: Found Cross-Validation F1 0.2829 for Trial 1, Iteration 63
# Debug: Found Iteration 64 for Trial 1
# Debug: Found Cross-Validation F1 0.5044 for Trial 1, Iteration 64
# Debug: Found Iteration 65 for Trial 1
# Debug: Found Cross-Validation F1 0.4133 for Trial 1, Iteration 65
# Debug: Found Iteration 66 for Trial 1
# Debug: Found Cross-Validation F1 0.2657 for Trial 1, Iteration 66
# Debug: Found Iteration 67 for Trial 1
# Debug: Found Cross-Validation F1 0.3236 for Trial 1, Iteration 67
# Debug: Found Iteration 68 for Trial 1
# Debug: Found Cross-Validation F1 0.2469 for Trial 1, Iteration 68
# Debug: Found Iteration 69 for Trial 1
# Debug: Found Cross-Validation F1 0.3424 for Trial 1, Iteration 69
# Debug: Found Iteration 70 for Trial 1
# Debug: Found Cross-Validation F1 0.4539 for Trial 1, Iteration 70
# Debug: Found Iteration 71 for Trial 1
# Debug: Found Cross-Validation F1 0.2831 for Trial 1, Iteration 71
# Debug: Found Iteration 72 for Trial 1
# Debug: Found Cross-Validation F1 0.5028 for Trial 1, Iteration 72
# Debug: Found Iteration 73 for Trial 1
# Debug: Found Cross-Validation F1 0.4443 for Trial 1, Iteration 73
# Debug: Found Iteration 74 for Trial 1
# Debug: Found Cross-Validation F1 0.465 for Trial 1, Iteration 74
# Debug: Found Iteration 75 for Trial 1
# Debug: Found Cross-Validation F1 0.4325 for Trial 1, Iteration 75
# Debug: Found Iteration 76 for Trial 1
# Debug: Found Cross-Validation F1 0.5078 for Trial 1, Iteration 76
# Debug: Found Iteration 77 for Trial 1
# Debug: Found Cross-Validation F1 0.4411 for Trial 1, Iteration 77
# Debug: Found Iteration 78 for Trial 1
# Debug: Found Cross-Validation F1 0.3366 for Trial 1, Iteration 78
# Debug: Found Iteration 79 for Trial 1
# Debug: Found Cross-Validation F1 0.4792 for Trial 1, Iteration 79
# Debug: Found Iteration 80 for Trial 1
# Debug: Found Cross-Validation F1 0.3949 for Trial 1, Iteration 80
# Debug: Found Iteration 81 for Trial 1
# Debug: Found Cross-Validation F1 0.4816 for Trial 1, Iteration 81
# Debug: Found Iteration 82 for Trial 1
# Debug: Found Cross-Validation F1 0.4259 for Trial 1, Iteration 82
# Debug: Found Iteration 83 for Trial 1
# Debug: Found Cross-Validation F1 0.2755 for Trial 1, Iteration 83
# Debug: Found Iteration 84 for Trial 1
# Debug: Found Cross-Validation F1 0.368 for Trial 1, Iteration 84
# Debug: Found Iteration 85 for Trial 1
# Debug: Found Cross-Validation F1 0.2803 for Trial 1, Iteration 85
# Debug: Found Iteration 86 for Trial 1
# Debug: Found Cross-Validation F1 0.5036 for Trial 1, Iteration 86
# Debug: Found Iteration 87 for Trial 1
# Debug: Found Cross-Validation F1 0.335 for Trial 1, Iteration 87
# Debug: Found Iteration 88 for Trial 1
# Debug: Found Cross-Validation F1 0.3458 for Trial 1, Iteration 88
# Debug: Found Iteration 89 for Trial 1
# Debug: Found Cross-Validation F1 0.3508 for Trial 1, Iteration 89
# Debug: Found Iteration 90 for Trial 1
# Debug: Found Cross-Validation F1 0.4293 for Trial 1, Iteration 90
# Debug: Found Iteration 91 for Trial 1
# Debug: Found Cross-Validation F1 0.4634 for Trial 1, Iteration 91
# Debug: Found Iteration 92 for Trial 1
# Debug: Found Cross-Validation F1 0.2461 for Trial 1, Iteration 92
# Debug: Found Iteration 93 for Trial 1
# Debug: Found Cross-Validation F1 0.2693 for Trial 1, Iteration 93
# Debug: Found Iteration 94 for Trial 1
# Debug: Found Cross-Validation F1 0.2773 for Trial 1, Iteration 94
# Debug: Found Iteration 95 for Trial 1
# Debug: Found Cross-Validation F1 0.1065 for Trial 1, Iteration 95
# Debug: Found Iteration 96 for Trial 1
# Debug: Found Cross-Validation F1 0.3654 for Trial 1, Iteration 96
# Debug: Found Iteration 97 for Trial 1
# Debug: Found Cross-Validation F1 0.4575 for Trial 1, Iteration 97
# Debug: Found Iteration 98 for Trial 1
# Debug: Found Cross-Validation F1 0.2829 for Trial 1, Iteration 98
# Debug: Found Iteration 99 for Trial 1
# Debug: Found Cross-Validation F1 0.4808 for Trial 1, Iteration 99
# Debug: Found Iteration 100 for Trial 1
# Debug: Found Cross-Validation F1 0.3032 for Trial 1, Iteration 100
# Debug: Found Iteration 101 for Trial 1
# Debug: Found Cross-Validation F1 0.3146 for Trial 1, Iteration 101
# Debug: Found Iteration 102 for Trial 1
# Debug: Found Cross-Validation F1 0.3925 for Trial 1, Iteration 102
# Debug: Found Iteration 103 for Trial 1
# Debug: Found Cross-Validation F1 0.4469 for Trial 1, Iteration 103
# Debug: Found Iteration 104 for Trial 1
# Debug: Found Cross-Validation F1 0.2707 for Trial 1, Iteration 104
# Debug: Found Iteration 105 for Trial 1
# Debug: Found Cross-Validation F1 0.4149 for Trial 1, Iteration 105
# Debug: Found Iteration 106 for Trial 1
# Debug: Found Cross-Validation F1 0.359 for Trial 1, Iteration 106
# Debug: Found Iteration 107 for Trial 1
# Debug: Found Cross-Validation F1 0.3056 for Trial 1, Iteration 107
# Debug: Found Iteration 108 for Trial 1
# Debug: Found Cross-Validation F1 0.2885 for Trial 1, Iteration 108
# Debug: Found Iteration 109 for Trial 1
# Debug: Found Cross-Validation F1 0.3268 for Trial 1, Iteration 109
# Debug: Found Iteration 110 for Trial 1
# Debug: Found Cross-Validation F1 0.328 for Trial 1, Iteration 110
# Debug: Found Iteration 111 for Trial 1
# Debug: Found Cross-Validation F1 0.3162 for Trial 1, Iteration 111
# Debug: Found Iteration 112 for Trial 1
# Debug: Found Cross-Validation F1 0.3066 for Trial 1, Iteration 112
# Debug: Found Iteration 113 for Trial 1
# Debug: Found Cross-Validation F1 0.2783 for Trial 1, Iteration 113
# Debug: Found Iteration 114 for Trial 1
# Debug: Found Cross-Validation F1 0.3771 for Trial 1, Iteration 114
# Debug: Found Iteration 115 for Trial 1
# Debug: Found Cross-Validation F1 0.3997 for Trial 1, Iteration 115
# Debug: Found Iteration 116 for Trial 1
# Debug: Found Cross-Validation F1 0.494 for Trial 1, Iteration 116
# Debug: Found Iteration 117 for Trial 1
# Debug: Found Cross-Validation F1 0.5122 for Trial 1, Iteration 117
# Debug: Found Iteration 118 for Trial 1
# Debug: Found Cross-Validation F1 0.4606 for Trial 1, Iteration 118
# Debug: Found Iteration 119 for Trial 1
# Debug: Found Cross-Validation F1 0.4954 for Trial 1, Iteration 119
# Debug: Found Iteration 120 for Trial 1
# Debug: Found Cross-Validation F1 0.2461 for Trial 1, Iteration 120
# Debug: Found Iteration 121 for Trial 1
# Debug: Found Cross-Validation F1 0.4107 for Trial 1, Iteration 121
# Debug: Found Iteration 122 for Trial 1
# Debug: Found Cross-Validation F1 0.4465 for Trial 1, Iteration 122
# Debug: Found Iteration 123 for Trial 1
# Debug: Found Cross-Validation F1 0.4716 for Trial 1, Iteration 123
# Debug: Found Iteration 124 for Trial 1
# Debug: Found Cross-Validation F1 0.5336 for Trial 1, Iteration 124
# Debug: Found Iteration 125 for Trial 1
# Debug: Found Cross-Validation F1 0.3935 for Trial 1, Iteration 125
# Debug: Found Iteration 126 for Trial 1
# Debug: Found Cross-Validation F1 0.4539 for Trial 1, Iteration 126
# Debug: Found Iteration 127 for Trial 1
# Debug: Found Cross-Validation F1 0.2893 for Trial 1, Iteration 127
# Debug: Found Iteration 128 for Trial 1
# Debug: Found Cross-Validation F1 0.2617 for Trial 1, Iteration 128
# Debug: Found Iteration 129 for Trial 1
# Debug: Found Cross-Validation F1 0.2649 for Trial 1, Iteration 129
# Debug: Found Iteration 130 for Trial 1
# Debug: Found Cross-Validation F1 0.4277 for Trial 1, Iteration 130
# Debug: Found Iteration 131 for Trial 1
# Debug: Found Cross-Validation F1 0.2833 for Trial 1, Iteration 131
# Debug: Found Iteration 132 for Trial 1
# Debug: Found Cross-Validation F1 0.4349 for Trial 1, Iteration 132
# Debug: Found Iteration 133 for Trial 1
# Debug: Found Cross-Validation F1 0.329 for Trial 1, Iteration 133
# Debug: Found Iteration 134 for Trial 1
# Debug: Found Cross-Validation F1 0.4742 for Trial 1, Iteration 134
# Debug: Found Iteration 135 for Trial 1
# Debug: Found Cross-Validation F1 0.3086 for Trial 1, Iteration 135
# Debug: Found Iteration 136 for Trial 1
# Debug: Found Cross-Validation F1 0.4365 for Trial 1, Iteration 136
# Debug: Found Iteration 137 for Trial 1
# Debug: Found Cross-Validation F1 0.4618 for Trial 1, Iteration 137
# Debug: Found Iteration 138 for Trial 1
# Debug: Found Cross-Validation F1 0.2707 for Trial 1, Iteration 138
# Debug: Found Iteration 139 for Trial 1
# Debug: Found Cross-Validation F1 0.4303 for Trial 1, Iteration 139
# Debug: Found Iteration 140 for Trial 1
# Debug: Found Cross-Validation F1 0.4503 for Trial 1, Iteration 140
# Debug: Found Iteration 141 for Trial 1
# Debug: Found Cross-Validation F1 0.514 for Trial 1, Iteration 141
# Debug: Found Iteration 142 for Trial 1
# Debug: Found Cross-Validation F1 0.2581 for Trial 1, Iteration 142
# Debug: Found Iteration 143 for Trial 1
# Debug: Found Cross-Validation F1 0.4962 for Trial 1, Iteration 143
# Debug: Found Iteration 144 for Trial 1
# Debug: Found Cross-Validation F1 0.4005 for Trial 1, Iteration 144
# Debug: Found Iteration 145 for Trial 1
# Debug: Found Cross-Validation F1 0.4085 for Trial 1, Iteration 145
# Debug: Found Iteration 146 for Trial 1
# Debug: Found Cross-Validation F1 0.4561 for Trial 1, Iteration 146
# Debug: Found Iteration 147 for Trial 1
# Debug: Found Cross-Validation F1 0.5537 for Trial 1, Iteration 147
# Debug: Found Iteration 148 for Trial 1
# Debug: Found Cross-Validation F1 0.3514 for Trial 1, Iteration 148
# Debug: Found Iteration 149 for Trial 1
# Debug: Found Cross-Validation F1 0.4782 for Trial 1, Iteration 149
# Debug: Found Iteration 150 for Trial 1
# Debug: Found Cross-Validation F1 0.336 for Trial 1, Iteration 150
# Debug: Found Iteration 151 for Trial 1
# Debug: Found Cross-Validation F1 0.3704 for Trial 1, Iteration 151
# Debug: Found Iteration 152 for Trial 1
# Debug: Found Cross-Validation F1 0.2117 for Trial 1, Iteration 152
# Debug: Found Iteration 153 for Trial 1
# Debug: Found Cross-Validation F1 0.2805 for Trial 1, Iteration 153
# Debug: Found Iteration 154 for Trial 1
# Debug: Found Cross-Validation F1 0.3656 for Trial 1, Iteration 154
# Debug: Found Iteration 155 for Trial 1
# Debug: Found Cross-Validation F1 0.3913 for Trial 1, Iteration 155
# Debug: Found Iteration 156 for Trial 1
# Debug: Found Cross-Validation F1 0.5062 for Trial 1, Iteration 156
# Debug: Found Iteration 157 for Trial 1
# Debug: Found Cross-Validation F1 0.2613 for Trial 1, Iteration 157
# Debug: Found Iteration 158 for Trial 1
# Debug: Found Cross-Validation F1 0.463 for Trial 1, Iteration 158
# Debug: Found Iteration 159 for Trial 1
# Debug: Found Cross-Validation F1 0.4988 for Trial 1, Iteration 159
# Debug: Found Iteration 160 for Trial 1
# Debug: Found Cross-Validation F1 0.4131 for Trial 1, Iteration 160
# Debug: Found Iteration 161 for Trial 1
# Debug: Found Cross-Validation F1 0.4614 for Trial 1, Iteration 161
# Debug: Found Iteration 162 for Trial 1
# Debug: Found Cross-Validation F1 0.4385 for Trial 1, Iteration 162
# Debug: Found Iteration 163 for Trial 1
# Debug: Found Cross-Validation F1 0.2461 for Trial 1, Iteration 163
# Debug: Found Iteration 164 for Trial 1
# Debug: Found Cross-Validation F1 0.4263 for Trial 1, Iteration 164
# Debug: Found Iteration 165 for Trial 1
# Debug: Found Cross-Validation F1 0.4808 for Trial 1, Iteration 165
# Debug: Found Iteration 166 for Trial 1
# Debug: Found Cross-Validation F1 0.298 for Trial 1, Iteration 166
# Debug: Found Iteration 167 for Trial 1
# Debug: Found Cross-Validation F1 0.4119 for Trial 1, Iteration 167
# Debug: Found Iteration 168 for Trial 1
# Debug: Found Cross-Validation F1 0.4053 for Trial 1, Iteration 168
# Debug: Found Iteration 169 for Trial 1
# Debug: Found Cross-Validation F1 0.2721 for Trial 1, Iteration 169
# Debug: Found Iteration 170 for Trial 1
# Debug: Found Cross-Validation F1 0.5336 for Trial 1, Iteration 170
# Debug: Found Iteration 171 for Trial 1
# Debug: Found Cross-Validation F1 0.4293 for Trial 1, Iteration 171
# Debug: Found Iteration 172 for Trial 1
# Debug: Found Cross-Validation F1 0.4365 for Trial 1, Iteration 172
# Debug: Found Iteration 173 for Trial 1
# Debug: Found Cross-Validation F1 0.3979 for Trial 1, Iteration 173
# Debug: Found Iteration 174 for Trial 1
# Debug: Found Cross-Validation F1 0.3594 for Trial 1, Iteration 174
# Debug: Found Iteration 175 for Trial 1
# Debug: Found Cross-Validation F1 0.4449 for Trial 1, Iteration 175
# Debug: Found Iteration 176 for Trial 1
# Debug: Found Cross-Validation F1 0.2887 for Trial 1, Iteration 176
# Debug: Found Iteration 177 for Trial 1
# Debug: Found Cross-Validation F1 0.4938 for Trial 1, Iteration 177
# Debug: Found Iteration 178 for Trial 1
# Debug: Found Cross-Validation F1 0.371 for Trial 1, Iteration 178
# Debug: Found Iteration 179 for Trial 1
# Debug: Found Cross-Validation F1 0.31 for Trial 1, Iteration 179
# Debug: Found Iteration 180 for Trial 1
# Debug: Found Cross-Validation F1 0.4345 for Trial 1, Iteration 180
# Debug: Found Iteration 181 for Trial 1
# Debug: Found Cross-Validation F1 0.4355 for Trial 1, Iteration 181
# Debug: Found Iteration 182 for Trial 1
# Debug: Found Cross-Validation F1 0.3404 for Trial 1, Iteration 182
# Debug: Found Iteration 183 for Trial 1
# Debug: Found Cross-Validation F1 0.3116 for Trial 1, Iteration 183
# Debug: Found Iteration 184 for Trial 1
# Debug: Found Cross-Validation F1 0.4249 for Trial 1, Iteration 184
# Debug: Found Iteration 185 for Trial 1
# Debug: Found Cross-Validation F1 0.3612 for Trial 1, Iteration 185
# Debug: Found Iteration 186 for Trial 1
# Debug: Found Cross-Validation F1 0.4567 for Trial 1, Iteration 186
# Debug: Found Iteration 187 for Trial 1
# Debug: Found Cross-Validation F1 0.4431 for Trial 1, Iteration 187
# Debug: Found Iteration 188 for Trial 1
# Debug: Found Cross-Validation F1 0.4549 for Trial 1, Iteration 188
# Debug: Found Iteration 189 for Trial 1
# Debug: Found Cross-Validation F1 0.3853 for Trial 1, Iteration 189
# Debug: Found Iteration 190 for Trial 1
# Debug: Found Cross-Validation F1 0.4225 for Trial 1, Iteration 190
# Debug: Found Iteration 191 for Trial 1
# Debug: Found Cross-Validation F1 0.3775 for Trial 1, Iteration 191
# Debug: Found Iteration 192 for Trial 1
# Debug: Found Cross-Validation F1 0.4467 for Trial 1, Iteration 192
# Debug: Found Iteration 193 for Trial 1
# Debug: Found Cross-Validation F1 0.4453 for Trial 1, Iteration 193
# Debug: Found Iteration 194 for Trial 1
# Debug: Found Cross-Validation F1 0.3012 for Trial 1, Iteration 194
# Debug: Found Iteration 195 for Trial 1
# Debug: Found Cross-Validation F1 0.3791 for Trial 1, Iteration 195
# Debug: Found Iteration 196 for Trial 1
# Debug: Found Cross-Validation F1 0.4728 for Trial 1, Iteration 196
# Debug: Found Iteration 197 for Trial 1
# Debug: Found Cross-Validation F1 0.4872 for Trial 1, Iteration 197
# Debug: Found Iteration 198 for Trial 1
# Debug: Found Cross-Validation F1 0.2537 for Trial 1, Iteration 198
# Debug: Found Iteration 199 for Trial 1
# Debug: Found Cross-Validation F1 0.4175 for Trial 1, Iteration 199
# Debug: Found Iteration 200 for Trial 1
# Debug: Found Cross-Validation F1 0.4521 for Trial 1, Iteration 200
# Debug: Starting summary collection for Trial 1
# Debug: Found Trial Time 159.4 seconds for Trial 1
# Debug: Found Best Trial F1 0.5537 for Trial 1
# Debug: Found Best Parameters for Trial 1: {'layer1_units': 2824, 'layer2_units': 1669, 'dropout1_rate': 0.098, 'dropout2_rate': 0.101}
# Debug: Saved summary for Trial 1
# Debug: Found Trial 2 during iterations
# Debug: Found Iteration 1 for Trial 2
# Debug: Found Cross-Validation F1 0.2493 for Trial 2, Iteration 1
# Debug: Found Iteration 2 for Trial 2
# Debug: Found Cross-Validation F1 0.3716 for Trial 2, Iteration 2
# Debug: Found Iteration 3 for Trial 2
# Debug: Found Cross-Validation F1 0.5034 for Trial 2, Iteration 3
# Debug: Found Iteration 4 for Trial 2
# Debug: Found Cross-Validation F1 0.524 for Trial 2, Iteration 4
# Debug: Found Iteration 5 for Trial 2
# Debug: Found Cross-Validation F1 0.5208 for Trial 2, Iteration 5
# Debug: Found Iteration 6 for Trial 2
# Debug: Found Cross-Validation F1 0.4844 for Trial 2, Iteration 6
# Debug: Found Iteration 7 for Trial 2
# Debug: Found Cross-Validation F1 0.4345 for Trial 2, Iteration 7
# Debug: Found Iteration 8 for Trial 2
# Debug: Found Cross-Validation F1 0.4762 for Trial 2, Iteration 8
# Debug: Found Iteration 9 for Trial 2
# Debug: Found Cross-Validation F1 0.4854 for Trial 2, Iteration 9
# Debug: Found Iteration 10 for Trial 2
# Debug: Found Cross-Validation F1 0.4409 for Trial 2, Iteration 10
# Debug: Found Iteration 11 for Trial 2
# Debug: Found Cross-Validation F1 0.2775 for Trial 2, Iteration 11
# Debug: Found Iteration 12 for Trial 2
# Debug: Found Cross-Validation F1 0.335 for Trial 2, Iteration 12
# Debug: Found Iteration 13 for Trial 2
# Debug: Found Cross-Validation F1 0.3362 for Trial 2, Iteration 13
# Debug: Found Iteration 14 for Trial 2
# Debug: Found Cross-Validation F1 0.3404 for Trial 2, Iteration 14
# Debug: Found Iteration 15 for Trial 2
# Debug: Found Cross-Validation F1 0.2467 for Trial 2, Iteration 15
# Debug: Found Iteration 16 for Trial 2
# Debug: Found Cross-Validation F1 0.4802 for Trial 2, Iteration 16
# Debug: Found Iteration 17 for Trial 2
# Debug: Found Cross-Validation F1 0.4734 for Trial 2, Iteration 17
# Debug: Found Iteration 18 for Trial 2
# Debug: Found Cross-Validation F1 0.2901 for Trial 2, Iteration 18
# Debug: Found Iteration 19 for Trial 2
# Debug: Found Cross-Validation F1 0.4772 for Trial 2, Iteration 19
# Debug: Found Iteration 20 for Trial 2
# Debug: Found Cross-Validation F1 0.2461 for Trial 2, Iteration 20
# Debug: Found Iteration 21 for Trial 2
# Debug: Found Cross-Validation F1 0.359 for Trial 2, Iteration 21
# Debug: Found Iteration 22 for Trial 2
# Debug: Found Cross-Validation F1 0.4329 for Trial 2, Iteration 184
# Debug: Found Iteration 185 for Trial 2
# Debug: Found Cross-Validation F1 0.2809 for Trial 2, Iteration 185
# Debug: Found Iteration 186 for Trial 2
# Debug: Found Cross-Validation F1 0.353 for Trial 2, Iteration 186
# Debug: Found Iteration 187 for Trial 2
# Debug: Found Cross-Validation F1 0.342 for Trial 2, Iteration 187
# Debug: Found Iteration 188 for Trial 2
# Debug: Found Cross-Validation F1 0.3875 for Trial 2, Iteration 188
# Debug: Found Iteration 189 for Trial 2
# Debug: Found Cross-Validation F1 0.4616 for Trial 2, Iteration 189
# Debug: Found Iteration 190 for Trial 2
# Debug: Found Cross-Validation F1 0.2647 for Trial 2, Iteration 190
# Debug: Found Iteration 191 for Trial 2
# Debug: Found Cross-Validation F1 0.4069 for Trial 2, Iteration 191
# Debug: Found Iteration 192 for Trial 2
# Debug: Found Cross-Validation F1 0.4541 for Trial 2, Iteration 192
# Debug: Found Iteration 193 for Trial 2
# Debug: Found Cross-Validation F1 0.4359 for Trial 2, Iteration 193
# Debug: Found Iteration 194 for Trial 2
# Debug: Found Cross-Validation F1 0.4133 for Trial 2, Iteration 194
# Debug: Found Iteration 195 for Trial 2
# Debug: Found Cross-Validation F1 0.4387 for Trial 2, Iteration 195
# Debug: Found Iteration 196 for Trial 2
# Debug: Found Cross-Validation F1 0.467 for Trial 2, Iteration 196
# Debug: Found Iteration 197 for Trial 2
# Debug: Found Cross-Validation F1 0.4644 for Trial 2, Iteration 197
# Debug: Found Iteration 198 for Trial 2
# Debug: Found Cross-Validation F1 0.2733 for Trial 2, Iteration 198
# Debug: Found Iteration 199 for Trial 2
# Debug: Found Cross-Validation F1 0.3799 for Trial 2, Iteration 199
# Debug: Found Iteration 200 for Trial 2
# Debug: Found Cross-Validation F1 0.4051 for Trial 2, Iteration 200
# Debug: Starting summary collection for Trial 2
# Debug: Found Trial Time 154.99 seconds for Trial 2
# Debug: Found Best Trial F1 0.5681 for Trial 2
# Debug: Found Best Parameters for Trial 2: {'layer1_units': 2949, 'layer2_units': 1717, 'dropout1_rate': 0.259, 'dropout2_rate': 0.173}
# Debug: Saved summary for Trial 2
# Debug: Found Trial 3 during iterations
# Debug: Found Iteration 1 for Trial 3
# Debug: Found Cross-Validation F1 0.3152 for Trial 3, Iteration 1
# Debug: Found Iteration 2 for Trial 3
# Debug: Found Cross-Validation F1 0.469 for Trial 3, Iteration 2
# Debug: Found Iteration 3 for Trial 3
# Debug: Found Cross-Validation F1 0.3564 for Trial 3, Iteration 3
# Debug: Found Iteration 4 for Trial 3
# Debug: Found Cross-Validation F1 0.5238 for Trial 3, Iteration 4
# Debug: Found Iteration 5 for Trial 3
# Debug: Found Cross-Validation F1 0.354 for Trial 3, Iteration 5
# Debug: Found Iteration 6 for Trial 3
# Debug: Found Cross-Validation F1 0.4267 for Trial 3, Iteration 6
# Debug: Found Iteration 7 for Trial 3
# Debug: Found Cross-Validation F1 0.4828 for Trial 3, Iteration 7
# Debug: Found Iteration 8 for Trial 3
# Debug: Found Cross-Validation F1 0.2461 for Trial 3, Iteration 8
# Debug: Found Iteration 9 for Trial 3
# Debug: Found Cross-Validation F1 0.3939 for Trial 3, Iteration 9
# Debug: Found Iteration 10 for Trial 3
# Debug: Found Cross-Validation F1 0.3965 for Trial 3, Iteration 10
# Debug: Found Iteration 11 for Trial 3
# Debug: Found Cross-Validation F1 0.2801 for Trial 3, Iteration 11
# Debug: Found Iteration 12 for Trial 3
# Debug: Found Cross-Validation F1 0.4279 for Trial 3, Iteration 12
# Debug: Found Iteration 13 for Trial 3
# Debug: Found Cross-Validation F1 0.325 for Trial 3, Iteration 13
# Debug: Found Iteration 14 for Trial 3
# Debug: Found Cross-Validation F1 0.4443 for Trial 3, Iteration 14
# Debug: Found Iteration 15 for Trial 3
# Debug: Found Cross-Validation F1 0.3927 for Trial 3, Iteration 15
# Debug: Found Iteration 16 for Trial 3
# Debug: Found Cross-Validation F1 0.3738 for Trial 3, Iteration 16
# Debug: Found Iteration 17 for Trial 3
# Debug: Found Cross-Validation F1 0.4493 for Trial 3, Iteration 17
# Debug: Found Iteration 18 for Trial 3
# Debug: Found Cross-Validation F1 0.4724 for Trial 3, Iteration 18
# Debug: Found Iteration 19 for Trial 3
# Debug: Found Cross-Validation F1 0.4866 for Trial 3, Iteration 19
# Debug: Found Iteration 20 for Trial 3
# Debug: Found Cross-Validation F1 0.4199 for Trial 3, Iteration 20
# Debug: Found Iteration 21 for Trial 3
# Debug: Found Cross-Validation F1 0.3662 for Trial 3, Iteration 21
# Debug: Found Iteration 22 for Trial 3
# Debug: Found Cross-Validation F1 0.472 for Trial 3, Iteration 22
# Debug: Found Iteration 23 for Trial 3
# Debug: Found Cross-Validation F1 0.3116 for Trial 3, Iteration 23
# Debug: Found Iteration 24 for Trial 3
# Debug: Found Cross-Validation F1 0.4153 for Trial 3, Iteration 24
# Debug: Found Iteration 25 for Trial 3
# Debug: Found Cross-Validation F1 0.4101 for Trial 3, Iteration 25
# Debug: Found Iteration 26 for Trial 3
# Debug: Found Cross-Validation F1 0.2781 for Trial 3, Iteration 26
# Debug: Found Iteration 27 for Trial 3
# Debug: Found Cross-Validation F1 0.5146 for Trial 3, Iteration 27
# Debug: Found Iteration 28 for Trial 3
# Debug: Found Cross-Validation F1 0.2811 for Trial 3, Iteration 28
# Debug: Found Iteration 29 for Trial 3
# Debug: Found Cross-Validation F1 0.2833 for Trial 3, Iteration 29
# Debug: Found Iteration 30 for Trial 3
# Debug: Found Cross-Validation F1 0.5042 for Trial 3, Iteration 30
# Debug: Found Iteration 31 for Trial 3
# Debug: Found Cross-Validation F1 0.4814 for Trial 3, Iteration 31
# Debug: Found Iteration 32 for Trial 3
# Debug: Found Cross-Validation F1 0.4732 for Trial 3, Iteration 32
# Debug: Found Iteration 33 for Trial 3
# Debug: Found Cross-Validation F1 0.4465 for Trial 3, Iteration 33
# Debug: Found Iteration 34 for Trial 3
# Debug: Found Cross-Validation F1 0.3324 for Trial 3, Iteration 34
# Debug: Found Iteration 35 for Trial 3
# Debug: Found Cross-Validation F1 0.4632 for Trial 3, Iteration 35
# Debug: Found Iteration 36 for Trial 3
# Debug: Found Cross-Validation F1 0.4345 for Trial 3, Iteration 36
# Debug: Found Iteration 37 for Trial 3
# Debug: Found Cross-Validation F1 0.4828 for Trial 3, Iteration 37
# Debug: Found Iteration 38 for Trial 3
# Debug: Found Cross-Validation F1 0.2709 for Trial 3, Iteration 38
# Debug: Found Iteration 39 for Trial 3
# Debug: Found Cross-Validation F1 0.3148 for Trial 3, Iteration 39
# Debug: Found Iteration 40 for Trial 3
# Debug: Found Cross-Validation F1 0.4658 for Trial 3, Iteration 40
# Debug: Found Iteration 41 for Trial 3
# Debug: Found Cross-Validation F1 0.4395 for Trial 3, Iteration 41
# Debug: Found Iteration 42 for Trial 3
# Debug: Found Cross-Validation F1 0.3322 for Trial 3, Iteration 42
# Debug: Found Iteration 43 for Trial 3
# Debug: Found Cross-Validation F1 0.2461 for Trial 3, Iteration 43
# Debug: Found Iteration 44 for Trial 3
# Debug: Found Cross-Validation F1 0.4427 for Trial 3, Iteration 44
# Debug: Found Iteration 45 for Trial 3
# Debug: Found Cross-Validation F1 0.2461 for Trial 3, Iteration 45
# Debug: Found Iteration 46 for Trial 3
# Debug: Found Cross-Validation F1 0.4249 for Trial 3, Iteration 46
# Debug: Found Iteration 47 for Trial 3
# Debug: Found Cross-Validation F1 0.4489 for Trial 3, Iteration 47
# Debug: Found Iteration 48 for Trial 3
# Debug: Found Cross-Validation F1 0.3436 for Trial 3, Iteration 48
# Debug: Found Iteration 49 for Trial 3
# Debug: Found Cross-Validation F1 0.5306 for Trial 3, Iteration 49
# Debug: Found Iteration 50 for Trial 3
# Debug: Found Cross-Validation F1 0.3178 for Trial 3, Iteration 50
# Debug: Found Iteration 51 for Trial 3
# Debug: Found Cross-Validation F1 0.4051 for Trial 3, Iteration 51
# Debug: Found Iteration 52 for Trial 3
# ...
# Debug: Found Iteration 59 for Trial 100
# Debug: Found Cross-Validation F1 0.2819 for Trial 100, Iteration 59
# Debug: Found Iteration 60 for Trial 100
# Debug: Found Cross-Validation F1 0.3394 for Trial 100, Iteration 60
# Debug: Found Iteration 61 for Trial 100
# Debug: Found Cross-Validation F1 0.3586 for Trial 100, Iteration 61
# Debug: Found Iteration 62 for Trial 100
# Debug: Found Cross-Validation F1 0.4824 for Trial 100, Iteration 62
# Debug: Found Iteration 63 for Trial 100
# Debug: Found Cross-Validation F1 0.4892 for Trial 100, Iteration 63
# Debug: Found Iteration 64 for Trial 100
# Debug: Found Cross-Validation F1 0.3044 for Trial 100, Iteration 64
# Debug: Found Iteration 65 for Trial 100
# Debug: Found Cross-Validation F1 0.3827 for Trial 100, Iteration 65
# Debug: Found Iteration 66 for Trial 100
# Debug: Found Cross-Validation F1 0.4439 for Trial 100, Iteration 66
# Debug: Found Iteration 67 for Trial 100
# Debug: Found Cross-Validation F1 0.502 for Trial 100, Iteration 67
# Debug: Found Iteration 68 for Trial 100
# Debug: Found Cross-Validation F1 0.3312 for Trial 100, Iteration 68
# Debug: Found Iteration 69 for Trial 100
# Debug: Found Cross-Validation F1 0.4183 for Trial 100, Iteration 69
# Debug: Found Iteration 70 for Trial 100
# Debug: Found Cross-Validation F1 0.4998 for Trial 100, Iteration 70
# Debug: Found Iteration 71 for Trial 100
# Debug: Found Cross-Validation F1 0.2713 for Trial 100, Iteration 71
# Debug: Found Iteration 72 for Trial 100
# Debug: Found Cross-Validation F1 0.3754 for Trial 100, Iteration 72
# Debug: Found Iteration 73 for Trial 100
# Debug: Found Cross-Validation F1 0.2954 for Trial 100, Iteration 73
# Debug: Found Iteration 74 for Trial 100
# Debug: Found Cross-Validation F1 0.4519 for Trial 100, Iteration 74
# Debug: Found Iteration 75 for Trial 100
# Debug: Found Cross-Validation F1 0.4331 for Trial 100, Iteration 75
# Debug: Found Iteration 76 for Trial 100
# Debug: Found Cross-Validation F1 0.534 for Trial 100, Iteration 76
# Debug: Found Iteration 77 for Trial 100
# Debug: Found Cross-Validation F1 0.5679 for Trial 100, Iteration 77
# Debug: Found Iteration 78 for Trial 100
# Debug: Found Cross-Validation F1 0.2807 for Trial 100, Iteration 78
# Debug: Found Iteration 79 for Trial 100
# Debug: Found Cross-Validation F1 0.4357 for Trial 100, Iteration 79
# Debug: Found Iteration 80 for Trial 100
# Debug: Found Cross-Validation F1 0.4109 for Trial 100, Iteration 80
# Debug: Found Iteration 81 for Trial 100
# Debug: Found Cross-Validation F1 0.3506 for Trial 100, Iteration 81
# Debug: Found Iteration 82 for Trial 100
# Debug: Found Cross-Validation F1 0.37 for Trial 100, Iteration 82
# Debug: Found Iteration 83 for Trial 100
# Debug: Found Cross-Validation F1 0.3442 for Trial 100, Iteration 83
# Debug: Found Iteration 84 for Trial 100
# Debug: Found Cross-Validation F1 0.4581 for Trial 100, Iteration 84
# Debug: Found Iteration 85 for Trial 100
# Debug: Found Cross-Validation F1 0.4019 for Trial 100, Iteration 85
# Debug: Found Iteration 86 for Trial 100
# Debug: Found Cross-Validation F1 0.482 for Trial 100, Iteration 86
# Debug: Found Iteration 87 for Trial 100
# Debug: Found Cross-Validation F1 0.4259 for Trial 100, Iteration 87
# Debug: Found Iteration 88 for Trial 100
# Debug: Found Cross-Validation F1 0.5082 for Trial 100, Iteration 88
# Debug: Found Iteration 89 for Trial 100
# Debug: Found Cross-Validation F1 0.4788 for Trial 100, Iteration 89
# Debug: Found Iteration 90 for Trial 100
# Debug: Found Cross-Validation F1 0.2986 for Trial 100, Iteration 90
# Debug: Found Iteration 91 for Trial 100
# Debug: Found Cross-Validation F1 0.4195 for Trial 100, Iteration 91
# Debug: Found Iteration 92 for Trial 100
# Debug: Found Cross-Validation F1 0.4203 for Trial 100, Iteration 92
# Debug: Found Iteration 93 for Trial 100
# Debug: Found Cross-Validation F1 0.2653 for Trial 100, Iteration 93
# Debug: Found Iteration 94 for Trial 100
# Debug: Found Cross-Validation F1 0.3472 for Trial 100, Iteration 94
# Debug: Found Iteration 95 for Trial 100
# Debug: Found Cross-Validation F1 0.3008 for Trial 100, Iteration 95
# Debug: Found Iteration 96 for Trial 100
# Debug: Found Cross-Validation F1 0.2711 for Trial 100, Iteration 96
# Debug: Found Iteration 97 for Trial 100
# Debug: Found Cross-Validation F1 0.373 for Trial 100, Iteration 97
# Debug: Found Iteration 98 for Trial 100
# Debug: Found Cross-Validation F1 0.5226 for Trial 100, Iteration 98
# Debug: Found Iteration 99 for Trial 100
# Debug: Found Cross-Validation F1 0.2665 for Trial 100, Iteration 99
# Debug: Found Iteration 100 for Trial 100
# Debug: Found Cross-Validation F1 0.2974 for Trial 100, Iteration 100
# Debug: Found Iteration 101 for Trial 100
# Debug: Found Cross-Validation F1 0.4179 for Trial 100, Iteration 101
# Debug: Found Iteration 102 for Trial 100
# Debug: Found Cross-Validation F1 0.4686 for Trial 100, Iteration 102
# Debug: Found Iteration 103 for Trial 100
# Debug: Found Cross-Validation F1 0.3678 for Trial 100, Iteration 103
# Debug: Found Iteration 104 for Trial 100
# Debug: Found Cross-Validation F1 0.369 for Trial 100, Iteration 104
# Debug: Found Iteration 105 for Trial 100
# Debug: Found Cross-Validation F1 0.4391 for Trial 100, Iteration 105
# Debug: Found Iteration 106 for Trial 100
# Debug: Found Cross-Validation F1 0.2915 for Trial 100, Iteration 106
# Debug: Found Iteration 107 for Trial 100
# Debug: Found Cross-Validation F1 0.3909 for Trial 100, Iteration 107
# Debug: Found Iteration 108 for Trial 100
# Debug: Found Cross-Validation F1 0.3871 for Trial 100, Iteration 108
# Debug: Found Iteration 109 for Trial 100
# Debug: Found Cross-Validation F1 0.3432 for Trial 100, Iteration 109
# Debug: Found Iteration 110 for Trial 100
# Debug: Found Cross-Validation F1 0.3608 for Trial 100, Iteration 110
# Debug: Found Iteration 111 for Trial 100
# Debug: Found Cross-Validation F1 0.2984 for Trial 100, Iteration 111
# Debug: Found Iteration 112 for Trial 100
# Debug: Found Cross-Validation F1 0.5076 for Trial 100, Iteration 112
# Debug: Found Iteration 113 for Trial 100
# Debug: Found Cross-Validation F1 0.3202 for Trial 100, Iteration 113
# Debug: Found Iteration 114 for Trial 100
# Debug: Found Cross-Validation F1 0.2713 for Trial 100, Iteration 114
# Debug: Found Iteration 115 for Trial 100
# Debug: Found Cross-Validation F1 0.2461 for Trial 100, Iteration 115
# Debug: Found Iteration 116 for Trial 100
# Debug: Found Cross-Validation F1 0.4003 for Trial 100, Iteration 116
# Debug: Found Iteration 117 for Trial 100
# Debug: Found Cross-Validation F1 0.4213 for Trial 100, Iteration 117
# Debug: Found Iteration 118 for Trial 100
# Debug: Found Cross-Validation F1 0.4277 for Trial 100, Iteration 118
# Debug: Found Iteration 119 for Trial 100
# Debug: Found Cross-Validation F1 0.3164 for Trial 100, Iteration 119
# Debug: Found Iteration 120 for Trial 100
# Debug: Found Cross-Validation F1 0.2743 for Trial 100, Iteration 120
# Debug: Found Iteration 121 for Trial 100
# Debug: Found Cross-Validation F1 0.4003 for Trial 100, Iteration 121
# Debug: Found Iteration 122 for Trial 100
# Debug: Found Cross-Validation F1 0.2587 for Trial 100, Iteration 122
# Debug: Found Iteration 123 for Trial 100
# Debug: Found Cross-Validation F1 0.305 for Trial 100, Iteration 123
# Debug: Found Iteration 124 for Trial 100
# Debug: Found Cross-Validation F1 0.3448 for Trial 100, Iteration 124
# Debug: Found Iteration 125 for Trial 100
# Debug: Found Cross-Validation F1 0.2751 for Trial 100, Iteration 125
# Debug: Found Iteration 126 for Trial 100
# Debug: Found Cross-Validation F1 0.4676 for Trial 100, Iteration 126
# Debug: Found Iteration 127 for Trial 100
# Debug: Found Cross-Validation F1 0.3791 for Trial 100, Iteration 127
# Debug: Found Iteration 128 for Trial 100
# Debug: Found Cross-Validation F1 0.4808 for Trial 100, Iteration 128
# Debug: Found Iteration 129 for Trial 100
# Debug: Found Cross-Validation F1 0.3496 for Trial 100, Iteration 129
# Debug: Found Iteration 130 for Trial 100
# Debug: Found Cross-Validation F1 0.2461 for Trial 100, Iteration 130
# Debug: Found Iteration 131 for Trial 100
# Debug: Found Cross-Validation F1 0.3562 for Trial 100, Iteration 131
# Debug: Found Iteration 132 for Trial 100
# Debug: Found Cross-Validation F1 0.2797 for Trial 100, Iteration 132
# Debug: Found Iteration 133 for Trial 100
# Debug: Found Cross-Validation F1 0.4529 for Trial 100, Iteration 133
# Debug: Found Iteration 134 for Trial 100
# Debug: Found Cross-Validation F1 0.4359 for Trial 100, Iteration 134
# Debug: Found Iteration 135 for Trial 100
# Debug: Found Cross-Validation F1 0.3738 for Trial 100, Iteration 135
# Debug: Found Iteration 136 for Trial 100
# Debug: Found Cross-Validation F1 0.3284 for Trial 100, Iteration 136
# Debug: Found Iteration 137 for Trial 100
# Debug: Found Cross-Validation F1 0.3062 for Trial 100, Iteration 137
# Debug: Found Iteration 138 for Trial 100
# Debug: Found Cross-Validation F1 0.4634 for Trial 100, Iteration 138
# Debug: Found Iteration 139 for Trial 100
# Debug: Found Cross-Validation F1 0.521 for Trial 100, Iteration 139
# Debug: Found Iteration 140 for Trial 100
# Debug: Found Cross-Validation F1 0.4676 for Trial 100, Iteration 140
# Debug: Found Iteration 141 for Trial 100
# Debug: Found Cross-Validation F1 0.2461 for Trial 100, Iteration 141
# Debug: Found Iteration 142 for Trial 100
# Debug: Found Cross-Validation F1 0.4658 for Trial 100, Iteration 142
# Debug: Found Iteration 143 for Trial 100
# Debug: Found Cross-Validation F1 0.4065 for Trial 100, Iteration 143
# Debug: Found Iteration 144 for Trial 100
# Debug: Found Cross-Validation F1 0.2583 for Trial 100, Iteration 144
# Debug: Found Iteration 145 for Trial 100
# Debug: Found Cross-Validation F1 0.535 for Trial 100, Iteration 145
# Debug: Found Iteration 146 for Trial 100
# Debug: Found Cross-Validation F1 0.2637 for Trial 100, Iteration 146
# Debug: Found Iteration 147 for Trial 100
# Debug: Found Cross-Validation F1 0.4936 for Trial 100, Iteration 147
# Debug: Found Iteration 148 for Trial 100
# Debug: Found Cross-Validation F1 0.4107 for Trial 100, Iteration 148
# Debug: Found Iteration 149 for Trial 100
# Debug: Found Cross-Validation F1 0.34 for Trial 100, Iteration 149
# Debug: Found Iteration 150 for Trial 100
# Debug: Found Cross-Validation F1 0.364 for Trial 100, Iteration 150
# Debug: Found Iteration 151 for Trial 100
# Debug: Found Cross-Validation F1 0.2863 for Trial 100, Iteration 151
# Debug: Found Iteration 152 for Trial 100
# Debug: Found Cross-Validation F1 0.4233 for Trial 100, Iteration 152
# Debug: Found Iteration 153 for Trial 100
# Debug: Found Cross-Validation F1 0.4245 for Trial 100, Iteration 153
# Debug: Found Iteration 154 for Trial 100
# Debug: Found Cross-Validation F1 0.4696 for Trial 100, Iteration 154
# Debug: Found Iteration 155 for Trial 100
# Debug: Found Cross-Validation F1 0.2461 for Trial 100, Iteration 155
# Debug: Found Iteration 156 for Trial 100
# Debug: Found Cross-Validation F1 0.4035 for Trial 100, Iteration 156
# Debug: Found Iteration 157 for Trial 100
# Debug: Found Cross-Validation F1 0.475 for Trial 100, Iteration 157
# Debug: Found Iteration 158 for Trial 100
# Debug: Found Cross-Validation F1 0.3789 for Trial 100, Iteration 158
# Debug: Found Iteration 159 for Trial 100
# Debug: Found Cross-Validation F1 0.3502 for Trial 100, Iteration 159
# Debug: Found Iteration 160 for Trial 100
# Debug: Found Cross-Validation F1 0.4754 for Trial 100, Iteration 160
# Debug: Found Iteration 161 for Trial 100
# Debug: Found Cross-Validation F1 0.4303 for Trial 100, Iteration 161
# Debug: Found Iteration 162 for Trial 100
# Debug: Found Cross-Validation F1 0.3394 for Trial 100, Iteration 162
# Debug: Found Iteration 163 for Trial 100
# Debug: Found Cross-Validation F1 0.2655 for Trial 100, Iteration 163
# Debug: Found Iteration 164 for Trial 100
# Debug: Found Cross-Validation F1 0.3378 for Trial 100, Iteration 164
# Debug: Found Iteration 165 for Trial 100
# Debug: Found Cross-Validation F1 0.5076 for Trial 100, Iteration 165
# Debug: Found Iteration 166 for Trial 100
# Debug: Found Cross-Validation F1 0.2461 for Trial 100, Iteration 166
# Debug: Found Iteration 167 for Trial 100
# Debug: Found Cross-Validation F1 0.4838 for Trial 100, Iteration 167
# Debug: Found Iteration 168 for Trial 100
# Debug: Found Cross-Validation F1 0.3544 for Trial 100, Iteration 168
# Debug: Found Iteration 169 for Trial 100
# Debug: Found Cross-Validation F1 0.4511 for Trial 100, Iteration 169
# Debug: Found Iteration 170 for Trial 100
# Debug: Found Cross-Validation F1 0.4345 for Trial 100, Iteration 170
# Debug: Found Iteration 171 for Trial 100
# Debug: Found Cross-Validation F1 0.5613 for Trial 100, Iteration 171
# Debug: Found Iteration 172 for Trial 100
# Debug: Found Cross-Validation F1 0.4503 for Trial 100, Iteration 172
# Debug: Found Iteration 173 for Trial 100
# Debug: Found Cross-Validation F1 0.2527 for Trial 100, Iteration 173
# Debug: Found Iteration 174 for Trial 100
# Debug: Found Cross-Validation F1 0.4459 for Trial 100, Iteration 174
# Debug: Found Iteration 175 for Trial 100
# Debug: Found Cross-Validation F1 0.4013 for Trial 100, Iteration 175
# Debug: Found Iteration 176 for Trial 100
# Debug: Found Cross-Validation F1 0.2441 for Trial 100, Iteration 176
# Debug: Found Iteration 177 for Trial 100
# Debug: Found Cross-Validation F1 0.2711 for Trial 100, Iteration 177
# Debug: Found Iteration 178 for Trial 100
# Debug: Found Cross-Validation F1 0.4383 for Trial 100, Iteration 178
# Debug: Found Iteration 179 for Trial 100
# Debug: Found Cross-Validation F1 0.48 for Trial 100, Iteration 179
# Debug: Found Iteration 180 for Trial 100
# Debug: Found Cross-Validation F1 0.3656 for Trial 100, Iteration 180
# Debug: Found Iteration 181 for Trial 100
# Debug: Found Cross-Validation F1 0.5162 for Trial 100, Iteration 181
# Debug: Found Iteration 182 for Trial 100
# Debug: Found Cross-Validation F1 0.2485 for Trial 100, Iteration 182
# Debug: Found Iteration 183 for Trial 100
# Debug: Found Cross-Validation F1 0.3604 for Trial 100, Iteration 183
# Debug: Found Iteration 184 for Trial 100
# Debug: Found Cross-Validation F1 0.5204 for Trial 100, Iteration 184
# Debug: Found Iteration 185 for Trial 100
# Debug: Found Cross-Validation F1 0.5058 for Trial 100, Iteration 185
# Debug: Found Iteration 186 for Trial 100
# Debug: Found Cross-Validation F1 0.4936 for Trial 100, Iteration 186
# Debug: Found Iteration 187 for Trial 100
# Debug: Found Cross-Validation F1 0.2633 for Trial 100, Iteration 187
# Debug: Found Iteration 188 for Trial 100
# Debug: Found Cross-Validation F1 0.4886 for Trial 100, Iteration 188
# Debug: Found Iteration 189 for Trial 100
# Debug: Found Cross-Validation F1 0.2803 for Trial 100, Iteration 189
# Debug: Found Iteration 190 for Trial 100
# Debug: Found Cross-Validation F1 0.501 for Trial 100, Iteration 190
# Debug: Found Iteration 191 for Trial 100
# Debug: Found Cross-Validation F1 0.5457 for Trial 100, Iteration 191
# Debug: Found Iteration 192 for Trial 100
# Debug: Found Cross-Validation F1 0.4123 for Trial 100, Iteration 192
# Debug: Found Iteration 193 for Trial 100
# Debug: Found Cross-Validation F1 0.3572 for Trial 100, Iteration 193
# Debug: Found Iteration 194 for Trial 100
# Debug: Found Cross-Validation F1 0.5036 for Trial 100, Iteration 194
# Debug: Found Iteration 195 for Trial 100
# Debug: Found Cross-Validation F1 0.3706 for Trial 100, Iteration 195
# Debug: Found Iteration 196 for Trial 100
# Debug: Found Cross-Validation F1 0.3074 for Trial 100, Iteration 196
# Debug: Found Iteration 197 for Trial 100
# Debug: Found Cross-Validation F1 0.3376 for Trial 100, Iteration 197
# Debug: Found Iteration 198 for Trial 100
# Debug: Found Cross-Validation F1 0.2936 for Trial 100, Iteration 198
# Debug: Found Iteration 199 for Trial 100
# Debug: Found Cross-Validation F1 0.3424 for Trial 100, Iteration 199
# Debug: Found Iteration 200 for Trial 100
# Debug: Found Cross-Validation F1 0.3338 for Trial 100, Iteration 200
# Debug: Starting summary collection for Trial 100
# Debug: Found Trial Time 138.15 seconds for Trial 100
# Debug: Found Best Trial F1 0.5679 for Trial 100
# Debug: Found Best Parameters for Trial 100: {'layer1_units': 2993, 'layer2_units': 1821, 'dropout1_rate': 0.181, 'dropout2_rate': 0.266}
# Debug: Saved summary for Trial 100
# Iteration data saved to: MLP_Random_10Jan25_7704200_ITERATION.csv
# Trial summary saved to: MLP_Random_10Jan25_7704200_SUMMARY.csv

# %%
# change to F1_Score
summary_df = summary_df.rename(columns={"Best_F1_Score": "F1_Score"})
# change Trial to Iteration

summary_df = summary_df.rename(columns={"Trial": "Iteration"})
#drop best parameters
summary_df = summary_df.drop(columns=["Best_Parameters"])
# save to csv
summary_df.to_csv(summary_file_path, index=False)

summary_df
# Out:
#     Iteration  F1_Score    Time
# 0           1    0.5537  159.40
# 1           2    0.5681  154.99
# 2           3    0.5398  142.18
# 3           4    0.5408  149.58
# 4           5    0.5667  131.00
# ..        ...       ...     ...
# 95         96    0.5401  139.98
# 96         97    0.5719  132.28
# 97         98    0.5529  134.13
# 98         99    0.5553  129.42
# 99        100    0.5679  138.15
#
# [100 rows x 3 columns]

# %%
#Swap columns Trial And Iteration Name but keep the values the same 
iteration_df = iteration_df.rename(columns={'Trial': 'Iteration', 'Iteration': 'Trial'})

iteration_df.to_csv('MLP_Random_10Jan25_7704200_TRIAL.csv', index=False)
iteration_df
# Out:
#        Iteration  Trial  F1_Score
# 0              1      1    0.2863
# 1              1      2    0.2515
# 2              1      3    0.3294
# 3              1      4    0.4113
# 4              1      5    0.3360
# ...          ...    ...       ...
# 19995        100    196    0.3074
# 19996        100    197    0.3376
# 19997        100    198    0.2936
# 19998        100    199    0.3424
# 19999        100    200    0.3338
#
# [20000 rows x 3 columns]

# %%
def get_max_f1_per_trial(iteration_df):
    """
    Get the maximum F1_Score for each Trial.

    Args:
        iteration_df (pd.DataFrame): DataFrame with columns "Trial", "Iteration", "F1_Score".

    Returns:
        pd.DataFrame: DataFrame with columns "Trial" and "Max_F1_Score", one row per trial.
    """
    # Group by Trial and get the maximum F1_Score
    random_final_df = iteration_df.groupby("Iteration", as_index=False)["F1_Score"].max()
    #random_final_df.rename(columns={"F1_Score": "Max_F1_Score"}, inplace=True)
    
    
    return random_final_df

random_final_df = get_max_f1_per_trial(iteration_df)

# %%
import pandas as pd

# Calculate the summary statistics
best_f1_score = summary_df['F1_Score'].max()
worst_f1_score = summary_df['F1_Score'].min()
avg_f1_score = summary_df['F1_Score'].mean()
std_dev_f1_score = summary_df['F1_Score'].std()
# calculate Average time and std dev of average time
avg_time = summary_df['Time'].mean()
std_dev_time = summary_df['Time'].std()

# Create the final summary DataFrame
final_summary = pd.DataFrame({
    'Best F1 Score': [best_f1_score],
    'Worst F1 Score': [worst_f1_score],
    'Average F1 Score': [avg_f1_score],
    'F1 Score Std Dev': [std_dev_f1_score],
    'Average Time': [avg_time],
    'Time Std Dev': [std_dev_time]
})

# Display the final summary DataFrame
final_summary.to_csv('MLP_Random_10Jan25_7704200_FINAL_SUMMARY.csv', index=False)
final_summary
# Out:
#    Best F1 Score  Worst F1 Score  Average F1 Score  F1 Score Std Dev  \
# 0         0.5743          0.5178          0.555339          0.011132
#
#    Average Time  Time Std Dev
# 0      140.3555      6.636634
